# %% [markdown]
# # Analisis Exploratorio

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from PIL import Image
import cv2

# %%
#base_path = r"/home/SantiagoInge/Estudios/Especializacion/Monografia/MonografiaMedicamentos/BasesDeDatos/imagenes_transformadasPNG"
#classes = os.listdir(base_path)
ejemplo = r'/home/SantiagoInge/Estudios/Especializacion/Monografia/MonografiaMedicamentos/AnalisisExploratorio/Acetaminofen500mg_BPM_LOTE.png'

# %%
img = Image.open(r'/home/SantiagoInge/Estudios/Especializacion/Monografia/MonografiaMedicamentos/AnalisisExploratorio/Acetaminofen500mg_BPM_LOTE.png')
#img

# %%
img_array = np.asarray(img)
img_array.shape
# Out:
# (1000, 1000, 3)

# %%
plt.imshow(img_array)

# %%
img_rojo = img_array.copy()
img_verde = img_array.copy()
img_azul = img_array.copy()
#plt.imshow(img_rojo)
img_rojo.shape
# Out:
# (1000, 1000, 3)

# %% [markdown]
# ## Seleccionando de a un canal de color

# %%
img_rojo[:,:,0] # 0 por que los canales son (R,G,B)
img_verde[:,:,1] # 1 por que los canales son (R,G,B)
img_azul[:,:,2] # 2 por que los canales son (R,G,B)
# Out:
# array([[254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        ...,
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254]],
#       shape=(1000, 1000), dtype=uint8)

# %%
#plt.imshow(img_verde[:,:,1],cmap='gray') # obteniendo los rojos de la imagen

# %%
#plt.imshow(img_rojo[:,:,1],cmap='gray') # obteniendo los rojos de la imagen

# %%
#plt.imshow(img_azul[:,:,2],cmap='gray') # obteniendo los rojos de la imagen

# %% [markdown]
# ### Mirando los canales de la imagen base

# %%
img_rojo[:,:,1] = 0
img_rojo[:,:,2] = 0
plt.imshow(img_rojo)
#img_rojo[:,:,0]

# %%
img_verde[:,:,2] = 0
img_verde[:,:,0] = 0
plt.imshow(img_verde)

# %%
img_azul[:,:,1] = 0
img_azul[:,:,0] = 0
plt.imshow(img_azul)

# %%
def resolution_size():
    pass
