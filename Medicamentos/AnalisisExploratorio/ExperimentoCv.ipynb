# %% [markdown]
# # Analisis Exploratorio

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from PIL import Image
import cv2

# %%
img = cv2.imread('/home/SantiagoInge/Estudios/Especializacion/Monografia/MonografiaMedicamentos/AnalisisExploratorio/Acetaminofen500mg_BPM_LOTE.png')
img.shape
# Out:
# (1000, 1000, 3)

# %%
plt.imshow(img)

# %%
img_arr = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_arr)

# %%
img_gris = cv2.imread('/home/SantiagoInge/Estudios/Especializacion/Monografia/MonografiaMedicamentos/AnalisisExploratorio/Acetaminofen500mg_BPM_LOTE.png', cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gris, cmap='gray')

# %% [markdown]
# ## Modificacion del size

# %%
img_arr.shape
# Out:
# (1000, 1000, 3)

# %%
img_peq = cv2.resize(img_arr, (500, 500))
plt.imshow(img_peq)
#img_peq.shape

# %%
img_mas_peq = cv2.resize(img_arr, (0, 0), img_arr,0.3,0.3)
plt.imshow(img_mas_peq)

# %% [markdown]
# ### Invirtiendo las imagenes

# %%
img_flip = cv2.flip(img_arr, 1)
plt.imshow(img_flip)

# %%
img_flip = cv2.flip(img_arr, 0)
plt.imshow(img_flip)

# %% [markdown]
# ### Guardado de imagenes

# %%
#cv2.imwrite('/home/SantiagoInge/Estudios/Especializacion/Monografia/MonografiaMedicamentos/AnalisisExploratorio/Acetaminofen500mg_BPM_LOTE_flip.png', img_flip)
