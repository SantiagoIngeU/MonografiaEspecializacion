# %%
import os
from IPython.display import display, HTML
from PIL import Image, UnidentifiedImageError
import base64
from io import BytesIO

# %%
def convertir_imagenesPNG_carpeta(carpeta_origen, carpeta_destino="/home/SantiagoInge/Estudios/Especializacion/Monografia/MonografiaMedicamentos/BasesDeDatos/imagenes_transformadasPNG", formato_salida="PNG"):

    os.makedirs(carpeta_destino, exist_ok=True)

    for nombre_archivo in os.listdir(carpeta_origen):
        ruta_origen = os.path.join(carpeta_origen, nombre_archivo)

        if not nombre_archivo.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif', '.webp','.avif')):
            continue

        try:
            with Image.open(ruta_origen) as img:
                if img.mode in ("RGBA", "P", "LA"):
                    img = img.convert("RGB")

                extension = ".png" if formato_salida.upper() == "PNG" else ".jpg"
                nuevo_nombre = os.path.splitext(nombre_archivo)[0] + extension
                ruta_destino = os.path.join(carpeta_destino, nuevo_nombre)

                if formato_salida.upper() == "JPEG":
                    img.save(ruta_destino, format="JPEG", quality=95)
                else:
                    img.save(ruta_destino, format="PNG")

                print(f"✅ Convertido: {nombre_archivo} → {nuevo_nombre}")

        except UnidentifiedImageError:
            print(f"⚠️  Imagen no válida (saltada): {nombre_archivo}")
            os.remove(ruta_origen)
            print(f"⚠️  Imagen Eliminada")
        except Exception as e:
            print(f"❌ Error procesando {nombre_archivo}: {e}")
    
    return os.path.abspath(carpeta_destino)

# %%
def generar_html_imagenes(carpeta, ancho=200):
    html = "<div style='display: flex; flex-wrap: wrap;'>"

    for nombre_archivo in os.listdir(carpeta):
        ruta_completa = os.path.join(carpeta, nombre_archivo)
        
        if not nombre_archivo.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp', '.webp','.avif')):
            continue

        # Cargar imagen y convertir a base64
        with Image.open(ruta_completa) as img:
            buffer = BytesIO()
            img.save(buffer, format="PNG")
            img_str = base64.b64encode(buffer.getvalue()).decode("utf-8")
            html += f"""
                <div style="margin: 5px; position: relative;">
                    <img src="data:image/png;base64,{img_str}" 
                         style="width: {ancho}px; border: 1px solid #ccc; transition: transform 0.2s;" 
                         onmouseover="this.style.transform='scale(2)'; this.style.zIndex='10'" 
                         onmouseout="this.style.transform='scale(1)'; this.style.zIndex='1'">
                    <div style="text-align: center; font-size: 12px;">{nombre_archivo}</div>
                </div>
            """

    html += "</div>"
    return HTML(html)

# %%
ruta_imagenes = '/home/SantiagoInge/Estudios/Especializacion/Monografia/MonografiaMedicamentos/BasesDeDatos/Medicamentos'
ruta_imagenesPNG = convertir_imagenesPNG_carpeta(ruta_imagenes)
# Out:
# ✅ Convertido: Diclofenaco_MK (otra copia).webp → Diclofenaco_MK (otra copia).png
# ✅ Convertido: Diclofenaco_OPHARMA (copia).jpg → Diclofenaco_OPHARMA (copia).png
# ✅ Convertido: Diclofenaco_OPHARMA.jpg → Diclofenaco_OPHARMA.png
# ✅ Convertido: Diclofenaco_MK (copia).webp → Diclofenaco_MK (copia).png
# ✅ Convertido: Diclofenaco_Portugal (otra copia).jpg → Diclofenaco_Portugal (otra copia).png
# ✅ Convertido: Diclofenaco_Portugal.jpg → Diclofenaco_Portugal.png
# ✅ Convertido: Diclofenaco_OPHARMA (otra copia).jpg → Diclofenaco_OPHARMA (otra copia).png
# ✅ Convertido: Ibuprofeno-Lacofa (copia).jpg → Ibuprofeno-Lacofa (copia).png
# ✅ Convertido: Diclofenaco_Portugal (copia).jpg → Diclofenaco_Portugal (copia).png
# ✅ Convertido: IBUPROFENO-LaSante (copia).jpg → IBUPROFENO-LaSante (copia).png
# ✅ Convertido: Ibuprofeno_MK (otra copia).jpg → Ibuprofeno_MK (otra copia).png
# ✅ Convertido: Ibuprofeno_MK (copia).jpg → Ibuprofeno_MK (copia).png
# ✅ Convertido: Ibuprofeno_MK.jpg → Ibuprofeno_MK.png
# ✅ Convertido: IBUPROFENO-LaSante (otra copia).jpg → IBUPROFENO-LaSante (otra copia).png
# ✅ Convertido: Ibuprofeno-Lacofa.jpg → Ibuprofeno-Lacofa.png
# ✅ Convertido: IBUPROFENO-LaSante.jpg → IBUPROFENO-LaSante.png
# ✅ Convertido: acetaminofen500mg_Genfar_LOTE.jpg → acetaminofen500mg_Genfar_LOTE.png
# ✅ Convertido: acetaminofen500mg_Genfar_LOTE (Copiar).jpg → acetaminofen500mg_Genfar_LOTE (Copiar).png
# ✅ Convertido: acetaminofen500mg_Genfar_LOTE (Copiar 2).jpg → acetaminofen500mg_Genfar_LOTE (Copiar 2).png
# ✅ Convertido: Acetaminofen500mg_BPM_LOTE.jpg → Acetaminofen500mg_BPM_LOTE.png
# ✅ Convertido: Acetaminofen500mg_BPM_LOTE (Copiar).jpg → Acetaminofen500mg_BPM_LOTE (Copiar).png
# ✅ Convertido: Acetaminofen500mg_BPM_LOTE (Copiar 2).jpg → Acetaminofen500mg_BPM_LOTE (Copiar 2).png
# ✅ Convertido: AcetaminofenViaOral500mg_Genfar_LOTE.jpg → AcetaminofenViaOral500mg_Genfar_LOTE.png
# ✅ Convertido: AcetaminofenViaOral500mg_Genfar_LOTE (Copiar).jpg → AcetaminofenViaOral500mg_Genfar_LOTE (Copiar).png
# ✅ Convertido: AcetaminofenViaOral500mg_Genfar_LOTE (Copiar 2).jpg → AcetaminofenViaOral500mg_Genfar_LOTE (Copiar 2).png
# ✅ Convertido: Acetaminofen500mg_MK_LOTE.jpg → Acetaminofen500mg_MK_LOTE.png
# ✅ Convertido: Acetaminofen500mg_MK_LOTE (Copiar).jpg → Acetaminofen500mg_MK_LOTE (Copiar).png
# ✅ Convertido: Acetaminofen500mg_MK_LOTE (Copiar 2).jpg → Acetaminofen500mg_MK_LOTE (Copiar 2).png
# ✅ Convertido: Amoxicilina500mg_AG_LOTE.jpg → Amoxicilina500mg_AG_LOTE.png
# ✅ Convertido: Amoxicilina500mg_AG_LOTE (Copiar).jpg → Amoxicilina500mg_AG_LOTE (Copiar).png
# ✅ Convertido: Amoxicilina500mg_AG_LOTE (Copiar 2).jpg → Amoxicilina500mg_AG_LOTE (Copiar 2).png
# ✅ Convertido: AmoxicilinaPolvo250mg_mk_LOTE.jpg → AmoxicilinaPolvo250mg_mk_LOTE.png
# ✅ Convertido: AmoxicilinaPolvo250mg_mk_LOTE (Copiar).jpg → AmoxicilinaPolvo250mg_mk_LOTE (Copiar).png
# ✅ Convertido: AmoxicilinaPolvo250mg_mk_LOTE (Copiar 2).jpg → AmoxicilinaPolvo250mg_mk_LOTE (Copiar 2).png
# ✅ Convertido: AMOXICILINAPolvo250MG_LaSante_LOTE.jpg → AMOXICILINAPolvo250MG_LaSante_LOTE.png
# ✅ Convertido: AMOXICILINAPolvo250MG_LaSante_LOTE (Copiar).jpg → AMOXICILINAPolvo250MG_LaSante_LOTE (Copiar).png
# ✅ Convertido: AMOXICILINAPolvo250MG_LaSante_LOTE (Copiar 2).jpg → AMOXICILINAPolvo250MG_LaSante_LOTE (Copiar 2).png
# ✅ Convertido: DiclofenacoViaOral50mg_Genfar_LOTE.jpg → DiclofenacoViaOral50mg_Genfar_LOTE.png
# ✅ Convertido: DiclofenacoViaOral50mg_Genfar_LOTE (Copiar).jpg → DiclofenacoViaOral50mg_Genfar_LOTE (Copiar).png
# ✅ Convertido: DiclofenacoViaOral50mg_Genfar_LOTE (Copiar 2).jpg → DiclofenacoViaOral50mg_Genfar_LOTE (Copiar 2).png
# ✅ Convertido: Ibuprofeno100mg_Chile_LOTE.jpg → Ibuprofeno100mg_Chile_LOTE.png
# ✅ Convertido: Ibuprofeno100mg_Chile_LOTE (Copiar).jpg → Ibuprofeno100mg_Chile_LOTE (Copiar).png
# ✅ Convertido: Ibuprofeno100mg_Chile_LOTE (Copiar 2).jpg → Ibuprofeno100mg_Chile_LOTE (Copiar 2).png
# ✅ Convertido: AmoxicilinaCapsula500mg_AG_LOTE.jpg → AmoxicilinaCapsula500mg_AG_LOTE.png
# ✅ Convertido: AmoxicilinaCapsula500mg_AG_LOTE (Copiar).jpg → AmoxicilinaCapsula500mg_AG_LOTE (Copiar).png
# ✅ Convertido: AmoxicilinaCapsula500mg_AG_LOTE (Copiar 2).jpg → AmoxicilinaCapsula500mg_AG_LOTE (Copiar 2).png
# ✅ Convertido: DiclofenacoTableta50mg_MK_LOTE.webp → DiclofenacoTableta50mg_MK_LOTE.png
# ✅ Convertido: DiclofenacoTableta50mg_MK_LOTE (Copiar).webp → DiclofenacoTableta50mg_MK_LOTE (Copiar).png
# ✅ Convertido: DiclofenacoTableta50mg_MK_LOTE (Copiar 2).webp → DiclofenacoTableta50mg_MK_LOTE (Copiar 2).png
# ✅ Convertido: IbuprofenoViaOral600mg_K_LOTE.jpg → IbuprofenoViaOral600mg_K_LOTE.png
# ✅ Convertido: IbuprofenoViaOral600mg_K_LOTE (Copiar).jpg → IbuprofenoViaOral600mg_K_LOTE (Copiar).png
# ✅ Convertido: IbuprofenoViaOral600mg_K_LOTE (Copiar 2).jpg → IbuprofenoViaOral600mg_K_LOTE (Copiar 2).png
# ✅ Convertido: Paracetamol500mg_Accord_LOTE.jpg → Paracetamol500mg_Accord_LOTE.png
# ✅ Convertido: Paracetamol500mg_Accord_LOTE (Copiar).jpg → Paracetamol500mg_Accord_LOTE (Copiar).png
# ✅ Convertido: Paracetamol500mg_Accord_LOTE (Copiar 2).jpg → Paracetamol500mg_Accord_LOTE (Copiar 2).png
# ✅ Convertido: ParacetamolTableta500mg_Ahorro_LOTE.jpg → ParacetamolTableta500mg_Ahorro_LOTE.png
# ✅ Convertido: ParacetamolTableta500mg_Ahorro_LOTE (Copiar).jpg → ParacetamolTableta500mg_Ahorro_LOTE (Copiar).png
# ✅ Convertido: ParacetamolTableta500mg_Ahorro_LOTE (Copiar 2).jpg → ParacetamolTableta500mg_Ahorro_LOTE (Copiar 2).png

# %%
#display(generar_html_imagenes(ruta_imagenesPNG))

# %% [markdown]
# ## Existencia de imagenes 4k ?

# %%
# Ruta de la carpeta con las imágenes
carpeta_imagenes = '/home/SantiagoInge/Estudios/Especializacion/Monografia/MonografiaMedicamentos/BasesDeDatos/imagenes_transformadasPNG'

# Resolución 4K mínima
ANCHO_4K = 3840
ALTO_4K = 2160

# Recorre los archivos en la carpeta
for nombre_archivo in os.listdir(carpeta_imagenes):
    
    if not nombre_archivo.lower().endswith('.png'):
        continue  # Solo procesamos .jpg
    
    ruta_completa = os.path.join(carpeta_imagenes, nombre_archivo)
    
    try:
        with Image.open(ruta_completa) as img:
            ancho, alto = img.size
            if ancho >= ANCHO_4K and alto >= ALTO_4K:
                print(f"👉 {nombre_archivo} ES 4K o mayor")
            else:
                print(f"{nombre_archivo}: {ancho}x{alto}")
                print(f"No tiene una resolucion mayor de o igual a 4K")  # Imprime el tamaño de cada imagen
    except Exception as e:
        print(f"⚠️ No se pudo procesar {nombre_archivo}: {e}")
# Out:
# Diclofenaco_MK (otra copia).png: 1200x1200
# No tiene una resolucion mayor de o igual a 4K
# Diclofenaco_OPHARMA (copia).png: 500x500
# No tiene una resolucion mayor de o igual a 4K
# Diclofenaco_OPHARMA.png: 500x500
# No tiene una resolucion mayor de o igual a 4K
# Diclofenaco_MK (copia).png: 1200x1200
# No tiene una resolucion mayor de o igual a 4K
# Diclofenaco_Portugal (otra copia).png: 900x900
# No tiene una resolucion mayor de o igual a 4K
# Diclofenaco_Portugal.png: 900x900
# No tiene una resolucion mayor de o igual a 4K
# Diclofenaco_OPHARMA (otra copia).png: 500x500
# No tiene una resolucion mayor de o igual a 4K
# Ibuprofeno-Lacofa (copia).png: 1000x833
# No tiene una resolucion mayor de o igual a 4K
# Diclofenaco_Portugal (copia).png: 900x900
# No tiene una resolucion mayor de o igual a 4K
# IBUPROFENO-LaSante (copia).png: 1500x1500
# No tiene una resolucion mayor de o igual a 4K
# Ibuprofeno_MK (otra copia).png: 1000x667
# No tiene una resolucion mayor de o igual a 4K
# Ibuprofeno_MK (copia).png: 1000x667
# No tiene una resolucion mayor de o igual a 4K
# Ibuprofeno_MK.png: 1000x667
# No tiene una resolucion mayor de o igual a 4K
# IBUPROFENO-LaSante (otra copia).png: 1500x1500
# No tiene una resolucion mayor de o igual a 4K
# Ibuprofeno-Lacofa.png: 1000x833
# No tiene una resolucion mayor de o igual a 4K
# IBUPROFENO-LaSante.png: 1500x1500
# No tiene una resolucion mayor de o igual a 4K
# acetaminofen500mg_Genfar_LOTE.png: 800x800
# No tiene una resolucion mayor de o igual a 4K
# acetaminofen500mg_Genfar_LOTE (Copiar).png: 800x800
# No tiene una resolucion mayor de o igual a 4K
# acetaminofen500mg_Genfar_LOTE (Copiar 2).png: 800x800
# No tiene una resolucion mayor de o igual a 4K
# Acetaminofen500mg_BPM_LOTE.png: 1000x1000
# No tiene una resolucion mayor de o igual a 4K
# Acetaminofen500mg_BPM_LOTE (Copiar).png: 1000x1000
# No tiene una resolucion mayor de o igual a 4K
# Acetaminofen500mg_BPM_LOTE (Copiar 2).png: 1000x1000
# No tiene una resolucion mayor de o igual a 4K
# AcetaminofenViaOral500mg_Genfar_LOTE.png: 1250x1120
# No tiene una resolucion mayor de o igual a 4K
# AcetaminofenViaOral500mg_Genfar_LOTE (Copiar).png: 1250x1120
# No tiene una resolucion mayor de o igual a 4K
# AcetaminofenViaOral500mg_Genfar_LOTE (Copiar 2).png: 1250x1120
# No tiene una resolucion mayor de o igual a 4K
# Acetaminofen500mg_MK_LOTE.png: 1200x1200
# No tiene una resolucion mayor de o igual a 4K
# Acetaminofen500mg_MK_LOTE (Copiar).png: 1200x1200
# No tiene una resolucion mayor de o igual a 4K
# Acetaminofen500mg_MK_LOTE (Copiar 2).png: 1200x1200
# No tiene una resolucion mayor de o igual a 4K
# Amoxicilina500mg_AG_LOTE.png: 2400x2400
# No tiene una resolucion mayor de o igual a 4K
# Amoxicilina500mg_AG_LOTE (Copiar).png: 2400x2400
# No tiene una resolucion mayor de o igual a 4K
# Amoxicilina500mg_AG_LOTE (Copiar 2).png: 2400x2400
# No tiene una resolucion mayor de o igual a 4K
# AmoxicilinaPolvo250mg_mk_LOTE.png: 1000x1000
# No tiene una resolucion mayor de o igual a 4K
# AmoxicilinaPolvo250mg_mk_LOTE (Copiar).png: 1000x1000
# No tiene una resolucion mayor de o igual a 4K
# AmoxicilinaPolvo250mg_mk_LOTE (Copiar 2).png: 1000x1000
# No tiene una resolucion mayor de o igual a 4K
# AMOXICILINAPolvo250MG_LaSante_LOTE.png: 1500x1500
# No tiene una resolucion mayor de o igual a 4K
# AMOXICILINAPolvo250MG_LaSante_LOTE (Copiar).png: 1500x1500
# No tiene una resolucion mayor de o igual a 4K
# AMOXICILINAPolvo250MG_LaSante_LOTE (Copiar 2).png: 1500x1500
# No tiene una resolucion mayor de o igual a 4K
# DiclofenacoViaOral50mg_Genfar_LOTE.png: 1000x667
# No tiene una resolucion mayor de o igual a 4K
# DiclofenacoViaOral50mg_Genfar_LOTE (Copiar).png: 1000x667
# No tiene una resolucion mayor de o igual a 4K
# DiclofenacoViaOral50mg_Genfar_LOTE (Copiar 2).png: 1000x667
# No tiene una resolucion mayor de o igual a 4K
# Ibuprofeno100mg_Chile_LOTE.png: 596x907
# No tiene una resolucion mayor de o igual a 4K
# Ibuprofeno100mg_Chile_LOTE (Copiar).png: 596x907
# No tiene una resolucion mayor de o igual a 4K
# Ibuprofeno100mg_Chile_LOTE (Copiar 2).png: 596x907
# No tiene una resolucion mayor de o igual a 4K
# AmoxicilinaCapsula500mg_AG_LOTE.png: 800x450
# No tiene una resolucion mayor de o igual a 4K
# AmoxicilinaCapsula500mg_AG_LOTE (Copiar).png: 800x450
# No tiene una resolucion mayor de o igual a 4K
# AmoxicilinaCapsula500mg_AG_LOTE (Copiar 2).png: 800x450
# No tiene una resolucion mayor de o igual a 4K
# DiclofenacoTableta50mg_MK_LOTE.png: 1200x1200
# No tiene una resolucion mayor de o igual a 4K
# DiclofenacoTableta50mg_MK_LOTE (Copiar).png: 1200x1200
# No tiene una resolucion mayor de o igual a 4K
# DiclofenacoTableta50mg_MK_LOTE (Copiar 2).png: 1200x1200
# No tiene una resolucion mayor de o igual a 4K
# IbuprofenoViaOral600mg_K_LOTE.png: 1200x628
# No tiene una resolucion mayor de o igual a 4K
# IbuprofenoViaOral600mg_K_LOTE (Copiar).png: 1200x628
# No tiene una resolucion mayor de o igual a 4K
# IbuprofenoViaOral600mg_K_LOTE (Copiar 2).png: 1200x628
# No tiene una resolucion mayor de o igual a 4K
# Paracetamol500mg_Accord_LOTE.png: 385x385
# No tiene una resolucion mayor de o igual a 4K
# Paracetamol500mg_Accord_LOTE (Copiar).png: 385x385
# No tiene una resolucion mayor de o igual a 4K
# Paracetamol500mg_Accord_LOTE (Copiar 2).png: 385x385
# No tiene una resolucion mayor de o igual a 4K
# ParacetamolTableta500mg_Ahorro_LOTE.png: 1600x1600
# No tiene una resolucion mayor de o igual a 4K
# ParacetamolTableta500mg_Ahorro_LOTE (Copiar).png: 1600x1600
# No tiene una resolucion mayor de o igual a 4K
# ParacetamolTableta500mg_Ahorro_LOTE (Copiar 2).png: 1600x1600
# No tiene una resolucion mayor de o igual a 4K
